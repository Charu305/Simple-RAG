# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings
import google.generativeai as genai

# %%
google_api_key = "AIzaSyC2on_wIP287EV7-9LHHZISVMdAlGGVw3s"
genai.configure(api_key=google_api_key)

# %%
from langchain_community.document_loaders import PyPDFLoader
loader=PyPDFLoader('Company HR Policy Handbook.pdf')
docs=loader.load()

# %%
docs
# Out:
# [Document(metadata={'producer': '', 'creator': 'WPS Writer', 'creationdate': '2026-01-05T19:41:57+05:30', 'author': 'ASUS', 'comments': '', 'company': '', 'keywords': '', 'moddate': '2026-01-05T19:41:57+05:30', 'sourcemodified': "D:20260105194157+05'30'", 'subject': '', 'title': '', 'trapped': '/False', 'source': 'Company HR Policy Handbook.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Company HR Policy Handbook\nCompany Overview:\nABC Technologies is a mid-sized software services company specializing in data analytics, cloud\nsolutions, and artificial intelligence. The company operates from Monday to Friday and follows a\nhybrid work model.\nWorking Hours Policy:\nStandard working hours are 9:30 AM to 6:30 PM.\nEmployees are expected to work 8 hours per day, excluding breaks.\nFlexible working hours are allowed with manager approval.\nLeave Policy:\nEmployees are entitled to 20 paid leaves per year.\nSick leave: 10 days annually\nCasual leave: 5 days annually\
# ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=200,
    chunk_overlap=20
)

documents = text_splitter.split_documents(docs)

# %%
documents[:5]
# Out:
# [Document(metadata={'producer': '', 'creator': 'WPS Writer', 'creationdate': '2026-01-05T19:41:57+05:30', 'author': 'ASUS', 'comments': '', 'company': '', 'keywords': '', 'moddate': '2026-01-05T19:41:57+05:30', 'sourcemodified': "D:20260105194157+05'30'", 'subject': '', 'title': '', 'trapped': '/False', 'source': 'Company HR Policy Handbook.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Company HR Policy Handbook\nCompany Overview:\nABC Technologies is a mid-sized software services company specializing in data analytics, cloud'),
# ...

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_community.vectorstores import Chroma
db = Chroma.from_documents(documents,GoogleGenerativeAIEmbeddings(model="models/embedding-001", google_api_key=google_api_key))

# %%
query = "What is the working hours?"
retireved_results=db.similarity_search(query)
print(retireved_results[0].page_content)
# Out:
# Employees are expected to work 8 hours per day, excluding breaks.
# Flexible working hours are allowed with manager approval.
# Leave Policy:
# Employees are entitled to 20 paid leaves per year.

# %%
query = "What is the Salary policy?"
retireved_results=db.similarity_search(query)
print(retireved_results[0].page_content)
# Out:
# Salary and Appraisal Policy:
# Salaries are credited on the last working day of each month.
# Annual appraisals are conducted in March.
# Performance ratings directly impact salary hikes and bonuses.
# Code of Conduct:
# Employees must maintain professional behavior at all times.
